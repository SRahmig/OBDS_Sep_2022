# %%
import numpy as np
import pandas as pd

# %%
Hs_df = pd.read_csv('/Users/susann/OBDS_course_Python/week_2/Homo_sapiens.GRCh38.107.gtf', sep="\t", header = None, comment="#")   # read .tsv file into memory
# Out:
# /var/folders/_y/kbhk52152hb2z95r0mn0x39w0000gr/T/ipykernel_61107/1090627024.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   Hs_df = pd.read_csv('/Users/susann/OBDS_course_Python/week_2/Homo_sapiens.GRCh38.107.gtf', sep="\t", header = None, comment="#")   # read .tsv file into memory

# %%
Hs_df
# Out:
#                   0               1                2        3        4  5  6  \
# 0                 1  ensembl_havana             gene  1471765  1497848  .  +
# 1                 1  ensembl_havana       transcript  1471765  1497848  .  +
# 2                 1  ensembl_havana             exon  1471765  1472089  .  +
# 3                 1  ensembl_havana              CDS  1471885  1472089  .  +
# 4                 1  ensembl_havana      start_codon  1471885  1471887  .  +
# ...             ...             ...              ...      ...      ... .. ..
# 3371239  KI270713.1         ensembl   five_prime_utr    32373    32528  .  -
# 3371240  KI270713.1         ensembl  three_prime_utr    31698    31841  .  -
# 3371241  KI270713.1         ensembl             gene    21861    22024  .  -
# 3371242  KI270713.1         ensembl       transcript    21861    22024  .  -
# 3371243  KI270713.1         ensembl             exon    21861    22024  .  -
#
# ...

# %%
Hs_df.columns=['seqname', 'source', 'feature', 'start', 'end', 'score', 'strand', 'frame', 'attribute']

# %%
Hs_df
# Out:
#             seqname          source          feature    start      end score  \
# 0                 1  ensembl_havana             gene  1471765  1497848     .
# 1                 1  ensembl_havana       transcript  1471765  1497848     .
# 2                 1  ensembl_havana             exon  1471765  1472089     .
# 3                 1  ensembl_havana              CDS  1471885  1472089     .
# 4                 1  ensembl_havana      start_codon  1471885  1471887     .
# ...             ...             ...              ...      ...      ...   ...
# 3371239  KI270713.1         ensembl   five_prime_utr    32373    32528     .
# 3371240  KI270713.1         ensembl  three_prime_utr    31698    31841     .
# 3371241  KI270713.1         ensembl             gene    21861    22024     .
# 3371242  KI270713.1         ensembl       transcript    21861    22024     .
# 3371243  KI270713.1         ensembl             exon    21861    22024     .
#
# ...

# %%
Hs_df['source'].unique()
# Out:
# array(['ensembl_havana', 'havana', 'ensembl', 'havana_tagene',
#        'ensembl_havana_tagene', 'mirbase', 'ensembl_tagene', 'insdc'],
#       dtype=object)

# %%
len(Hs_df['source'].unique())
# Out:
# 8

# %%
ens_df=Hs_df.query("source == 'ensembl_havana'")

# %%
ens_df
# Out:
#         seqname          source          feature     start       end score  \
# 0             1  ensembl_havana             gene   1471765   1497848     .
# 1             1  ensembl_havana       transcript   1471765   1497848     .
# 2             1  ensembl_havana             exon   1471765   1472089     .
# 3             1  ensembl_havana              CDS   1471885   1472089     .
# 4             1  ensembl_havana      start_codon   1471885   1471887     .
# ...         ...             ...              ...       ...       ...   ...
# 3370044      21  ensembl_havana             exon  46445284  46445769     .
# 3370045      21  ensembl_havana              CDS  46445284  46445324     .
# 3370046      21  ensembl_havana       stop_codon  46445325  46445327     .
# 3370047      21  ensembl_havana   five_prime_utr  46324156  46324228     .
# 3370048      21  ensembl_havana  three_prime_utr  46445328  46445769     .
#
# ...

# %%
ens_df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 ens_df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
ens_df.shape
# Out:
# (714608, 9)

# %%
Hs_df.groupby('feature')

# %%
Hs_df
# Out:
#             seqname          source          feature    start      end score  \
# 0                 1  ensembl_havana             gene  1471765  1497848     .
# 1                 1  ensembl_havana       transcript  1471765  1497848     .
# 2                 1  ensembl_havana             exon  1471765  1472089     .
# 3                 1  ensembl_havana              CDS  1471885  1472089     .
# 4                 1  ensembl_havana      start_codon  1471885  1471887     .
# ...             ...             ...              ...      ...      ...   ...
# 3371239  KI270713.1         ensembl   five_prime_utr    32373    32528     .
# 3371240  KI270713.1         ensembl  three_prime_utr    31698    31841     .
# 3371241  KI270713.1         ensembl             gene    21861    22024     .
# 3371242  KI270713.1         ensembl       transcript    21861    22024     .
# 3371243  KI270713.1         ensembl             exon    21861    22024     .
#
# ...

# %%
Hs_df["feature"].value_counts()
# Out:
# exon               1624585
# CDS                 871196
# transcript          251121
# three_prime_utr     203201
# five_prime_utr      171504
# start_codon          96934
# stop_codon           90724
# gene                 61860
# Selenocysteine         119
# Name: feature, dtype: int64

# %%
genes_df=Hs_df.query("feature == 'gene'")

# %%
genes_df.shape
# Out:
# (61860, 9)

# %%
genes_df = genes_df.assign(gene_length = genes_df['end'] - genes_df['start'])

# %%
genes_df
# Out:
#             seqname          source feature    start      end score strand  \
# 0                 1  ensembl_havana    gene  1471765  1497848     .      +
# 107               1          havana    gene  2212523  2220738     .      +
# 111               1          havana    gene   629062   629433     .      +
# 114               1          havana    gene  8786211  8786913     .      -
# 117               1          havana    gene   634376   634922     .      +
# ...             ...             ...     ...      ...      ...   ...    ...
# 3371150  KI270711.1         ensembl    gene     4612    29626     .      -
# 3371224  KI270713.1         ensembl    gene    30437    30580     .      -
# 3371227  KI270713.1         ensembl    gene    35407    35916     .      +
# 3371233  KI270713.1         ensembl    gene    31698    32528     .      -
# 3371241  KI270713.1         ensembl    gene    21861    22024     .      -
#
# ...

# %%
genes_df['gene_length'].mean()
# Out:
# 32626.786744261233

# %%
genes_df.describe()
# Out:
#               start           end   gene_length
# count  6.186000e+04  6.186000e+04  6.186000e+04
# mean   7.403611e+07  7.406874e+07  3.262679e+04
# std    5.558790e+07  5.559096e+07  9.230443e+04
# min    5.770000e+02  6.470000e+02  7.000000e+00
# 25%    3.021300e+07  3.021955e+07  5.670000e+02
# 50%    6.061628e+07  6.065367e+07  3.553500e+03
# 75%    1.092006e+08  1.092546e+08  2.519725e+04
# max    2.489366e+08  2.489370e+08  2.473538e+06

# %%
genes_df['gene_length'].median()
# Out:
# 3553.5

# %%
genes_sort_df = genes_df.sort_values(by=['gene_length'], ascending=False)

# %%
genes_sort_df.iloc[0:10,]
# Out:
#         seqname          source feature      start        end score strand  \
# 2679474      16  ensembl_havana    gene    5239802    7713340     .      +
# 1297140       7  ensembl_havana    gene  146116002  148420998     .      +
# 1733179       9  ensembl_havana    gene    8314246   10613002     .      -
# 1514121       X  ensembl_havana    gene   31097677   33339609     .      -
# 1850816      11  ensembl_havana    gene   83455012   85627922     .      -
# 1601567       8  ensembl_havana    gene    2935353    4994972     .      -
# 3030998      20  ensembl_havana    gene   13995369   16053197     .      +
# 1104549       6  ensembl_havana    gene   63719980   65707226     .      -
# 338522        2          havana    gene  140231423  142131016     .      -
# 2041854      10  ensembl_havana    gene   65912457   67763637     .      -
#
#         frame                                          attribute  gene_length
# ...

# %%
len(genes_sort_df)
# Out:
# 61860

# %%
genes_sort_df.iloc[len(genes_sort_df)-20:len(genes_sort_df),]
# Out:
#         seqname  source feature      start        end score strand frame  \
# 2418653      14  havana    gene  105893542  105893561     .      -     .
# 2489695      15  havana    gene   20004797   20004815     .      -     .
# 2467325      15  havana    gene   21011451   21011469     .      -     .
# 2418624      14  havana    gene  105884870  105884888     .      -     .
# 2418616      14  havana    gene  105881539  105881556     .      -     .
# 2418705      14  havana    gene  105910410  105910427     .      -     .
# 2418645      14  havana    gene  105891191  105891207     .      -     .
# 2467826      15  havana    gene   21017800   21017816     .      -     .
# 2462756      15  havana    gene   20011153   20011169     .      -     .
# 2418701      14  havana    gene  105909907  105909923     .      -     .
# 2418669      14  havana    gene  105900638  105900654     .      -     .
# 2418725      14  havana    gene  105919502  105919518     .      -     .
# ...
