# %%
import numpy as np

# %%
import pandas as pd

# %%
idx_df = pd.read_csv('/Users/susann/OBDS_course_Python/week_2/excercise1_idxstats.tsv', sep="\t", header = None)   # read .tsv file into memory

# %%
idx_df.head()
# Out:
#       0          1        2      3
# 0  chrM      16571      226      2
# 1  chr1  249250621  1202908  11586
# 2  chr2  243199373  1179409  11950
# 3  chr3  198022430   956939   7894
# 4  chr4  191154276   841065   8496

# %%
# !cd OBDS_course_Python
# !pwd
# Out:
# /Users/susann

# %%
idx_df.columns=['sequence name', 'sequence length', 'mapped segments', 'unmapped segments']

# %%
idx_df.head()
# Out:
#   sequence name  sequence length  mapped segments  unmapped segments
# 0          chrM            16571              226                  2
# 1          chr1        249250621          1202908              11586
# 2          chr2        243199373          1179409              11950
# 3          chr3        198022430           956939               7894
# 4          chr4        191154276           841065               8496

# %%
idx_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sequence name      26 non-null     object
#  1   sequence length    26 non-null     int64
#  2   mapped segments    26 non-null     int64
#  3   unmapped segments  26 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 960.0+ bytes

# %%
idx_df.describe()
# Out:
#        sequence length  mapped segments  unmapped segments
# count     2.600000e+01     2.600000e+01       2.600000e+01
# mean      1.190652e+08     5.602201e+05       5.106119e+04
# std       6.568174e+07     3.330361e+05       2.292555e+05
# min       0.000000e+00     0.000000e+00       2.000000e+00
# 25%       6.678845e+07     3.426832e+05       4.109500e+03
# 50%       1.245109e+08     5.281825e+05       6.406000e+03
# 75%       1.581716e+08     8.117202e+05       7.852500e+03
# max       2.492506e+08     1.202908e+06       1.174990e+06

# %%
idx_df.shape
# Out:
# (26, 4)

# %%
idx_df.index
# Out:
# RangeIndex(start=0, stop=26, step=1)

# %%
idx_df2 = idx_df.iloc[6:13, ]

# %%
idx_df2
# Out:
#    sequence name  sequence length  mapped segments  unmapped segments
# 6           chr6        171115067           851357               6930
# 7           chr7        159138663           639203               7728
# 8           chr8        146364022           951606               8874
# 9           chr9        141213431           603020               6937
# 10         chr10        135534747           692429              10325
# 11         chr11        135006516           660885               7635
# 12         chr12        133851895           728753               6993

# %%
chr_mapped = idx_df[['sequence name', 'mapped segments']]

# %%
chr_mapped
# Out:
#    sequence name  mapped segments
# 0           chrM              226
# 1           chr1          1202908
# 2           chr2          1179409
# 3           chr3           956939
# 4           chr4           841065
# 5           chr5           839376
# 6           chr6           851357
# 7           chr7           639203
# 8           chr8           951606
# 9           chr9           603020
# 10         chr10           692429
# 11         chr11           660885
# 12         chr12           728753
# 13         chr13           523741
# 14         chr14           480831
# 15         chr15           447954
# 16         chr16           483073
# 17         chr17           532624
# 18         chr18           319957
# 19         chr19           407712
# 20         chr20           321007
# 21         chr21           175650
# 22         chr22           224761
# 23          chrX           490861
# 24          chrY            10375
# 25             *                0

# %%
chr_mapped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sequence name    26 non-null     object
#  1   mapped segments  26 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 544.0+ bytes

# %%
chr_mapped.to_csv('mapped_reads_per_chr.tsv', sep="\t")

# %%
chr_mapped_read = pd.read_csv('mapped_reads_per_chr.tsv', sep="\t", header = None)   # read .tsv file into memory

# %%
chr_mapped_read
# Out:
#        0              1                2
# 0    NaN  sequence name  mapped segments
# 1    0.0           chrM              226
# 2    1.0           chr1          1202908
# 3    2.0           chr2          1179409
# 4    3.0           chr3           956939
# 5    4.0           chr4           841065
# 6    5.0           chr5           839376
# 7    6.0           chr6           851357
# 8    7.0           chr7           639203
# 9    8.0           chr8           951606
# 10   9.0           chr9           603020
# 11  10.0          chr10           692429
# 12  11.0          chr11           660885
# 13  12.0          chr12           728753
# 14  13.0          chr13           523741
# 15  14.0          chr14           480831
# 16  15.0          chr15           447954
# 17  16.0          chr16           483073
# 18  17.0          chr17           532624
# 19  18.0          chr18           319957
# 20  19.0          chr19           407712
# 21  20.0          chr20           321007
# ...

# %%
chr_mapped
# Out:
#    sequence name  mapped segments
# 0           chrM              226
# 1           chr1          1202908
# 2           chr2          1179409
# 3           chr3           956939
# 4           chr4           841065
# 5           chr5           839376
# 6           chr6           851357
# 7           chr7           639203
# 8           chr8           951606
# 9           chr9           603020
# 10         chr10           692429
# 11         chr11           660885
# 12         chr12           728753
# 13         chr13           523741
# 14         chr14           480831
# 15         chr15           447954
# 16         chr16           483073
# 17         chr17           532624
# 18         chr18           319957
# 19         chr19           407712
# 20         chr20           321007
# 21         chr21           175650
# 22         chr22           224761
# 23          chrX           490861
# 24          chrY            10375
# 25             *                0

# %%
idx_df = idx_df.assign(reads_per_base = idx_df['mapped segments'] / idx_df['sequence length'])

# %%
idx_df
# Out:
#    sequence name  sequence length  mapped segments  unmapped segments  \
# 0           chrM            16571              226                  2
# 1           chr1        249250621          1202908              11586
# 2           chr2        243199373          1179409              11950
# 3           chr3        198022430           956939               7894
# 4           chr4        191154276           841065               8496
# 5           chr5        180915260           839376               7313
# 6           chr6        171115067           851357               6930
# 7           chr7        159138663           639203               7728
# 8           chr8        146364022           951606               8874
# 9           chr9        141213431           603020               6937
# 10         chr10        135534747           692429              10325
# 11         chr11        135006516           660885               7635
# ...

# %%
mask = idx_df['reads_per_base']>0.005

# %%
mask
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10     True
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16     True
# 17     True
# 18    False
# 19     True
# 20     True
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# Name: reads_per_base, dtype: bool

# %%
idx_df = idx_df.assign(length_Mbs = idx_df['sequence length'] / 1000000)

# %%
idx_df
# Out:
#    sequence name  sequence length  mapped segments  unmapped segments  \
# 0           chrM            16571              226                  2
# 1           chr1        249250621          1202908              11586
# 2           chr2        243199373          1179409              11950
# 3           chr3        198022430           956939               7894
# 4           chr4        191154276           841065               8496
# 5           chr5        180915260           839376               7313
# 6           chr6        171115067           851357               6930
# 7           chr7        159138663           639203               7728
# 8           chr8        146364022           951606               8874
# 9           chr9        141213431           603020               6937
# 10         chr10        135534747           692429              10325
# 11         chr11        135006516           660885               7635
# ...

# %%
mask2 = (idx_df['reads_per_base']>0.005) & (idx_df['length_Mbs']<100)

# %%
mask2
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17     True
# 18    False
# 19     True
# 20     True
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# dtype: bool

# %%
idx_df.query("reads_per_base >0.005 & length_Mbs < 100")
# Out:
#    sequence name  sequence length  mapped segments  unmapped segments  \
# 0           chrM            16571              226                  2
# 16         chr16         90354753           483073               5439
# 17         chr17         81195210           532624               5339
# 19         chr19         59128983           407712               5882
# 20         chr20         63025520           321007               3280
#
#     reads_per_base  length_Mbs
# 0         0.013638    0.016571
# 16        0.005346   90.354753
# 17        0.006560   81.195210
# 19        0.006895   59.128983
# 20        0.005093   63.025520

# %%
idx_df = idx_df.drop ('reads_per_base', axis=1)

# %%
idx_df
# Out:
#    sequence name  sequence length  mapped segments  unmapped segments  \
# 0           chrM            16571              226                  2
# 1           chr1        249250621          1202908              11586
# 2           chr2        243199373          1179409              11950
# 3           chr3        198022430           956939               7894
# 4           chr4        191154276           841065               8496
# 5           chr5        180915260           839376               7313
# 6           chr6        171115067           851357               6930
# 7           chr7        159138663           639203               7728
# 8           chr8        146364022           951606               8874
# 9           chr9        141213431           603020               6937
# 10         chr10        135534747           692429              10325
# 11         chr11        135006516           660885               7635
# ...

# %%
idx_df.sort_values(by=['length_Mbs'])
# Out:
#    sequence name  sequence length  mapped segments  unmapped segments  \
# 25             *                0                0            1174990
# 0           chrM            16571              226                  2
# 21         chr21         48129895           175650               2351
# 22         chr22         51304566           224761               2206
# 19         chr19         59128983           407712               5882
# 24          chrY         59373566            10375               3028
# 20         chr20         63025520           321007               3280
# 18         chr18         78077248           319957               4373
# 17         chr17         81195210           532624               5339
# 16         chr16         90354753           483073               5439
# 15         chr15        102531392           447954               3936
# 14         chr14        107349540           480831               4255
# ...

# %%
local()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [92], in <cell line: 1>()
# ----> 1 local()
#
# NameError: name 'local' is not defined

# %%
global()
# Out:
#   Input In [93]
#     global()
#           ^
# SyntaxError: invalid syntax
